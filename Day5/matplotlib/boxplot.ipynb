# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6,7,15]
x1=[2,3,4,6,8,9,5,3,30]
x2=[6,4,4,3,7,4,8,2,20]
y=[x,x1,x2]
plt.boxplot(y,widths=0.3,tick_labels=["python","java","c++"],showmeans=True,sym="r",
           boxprops=dict(color='b'))
plt.show()
