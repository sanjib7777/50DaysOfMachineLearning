# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[3,5,3,5,7]
plt.step(x,y,marker="o",color="r",mfc="b",label="python")
plt.title("step plot example")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.grid()
plt.legend(loc=4)
plt.show()
