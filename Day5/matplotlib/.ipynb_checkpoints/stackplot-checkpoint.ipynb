# %% [markdown]
# # stack plot

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
area1=[1,2,7,5,3]
area2=[2,5,7,3,3]
area3=[1,8,1,4,3]
l=["a1","a2","a3"]
plt.stackplot(x,area1,area2,area3,labels=l,colors=['r','b','g'])
plt.title("python")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.legend()
plt.show()
