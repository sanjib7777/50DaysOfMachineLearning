# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
x=np.random.randint(20,100,(50))
result = ','.join(map(str,x))
print(result)
# Out:
# 73,44,51,75,64,34,99,31,44,20,34,90,75,85,90,80,96,23,65,58,39,52,62,65,50,26,51,38,87,23,45,80,56,57,30,22,38,93,94,83,27,79,46,42,60,69,37,77,87,29

# %%
no=[73,44,51,75,64,34,99,31,44,20,34,90,75,85,90,80,96,23,65,58,39,52,62,65,50,26,51,38,87,23,45,80,56]
plt.hist(no,"auto",(0,150),edgecolor='b',rwidth=0.7,align="mid",label="student")
plt.title("student")
plt.axvline(60,color='r',label='line')
plt.legend()
plt.show()
