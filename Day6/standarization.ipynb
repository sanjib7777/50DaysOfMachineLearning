# %%
import pandas as pd

# %%
df=pd.read_csv("Social_Network_Ads.csv")
df.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %% [markdown]
# # train test split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(df.drop('Purchased',axis=1),df['Purchased'],test_size=0.3)

# %%
X_train.head()
# Out:
#      Age  EstimatedSalary
# 217   40            78000
# 132   30            87000
# 220   41            80000
# 248   41            52000
# 135   23            63000

# %%
X_train.describe()
# Out:
#               Age  EstimatedSalary
# count  280.000000       280.000000
# mean    37.839286     68217.857143
# std     10.430478     33926.534097
# min     18.000000     15000.000000
# 25%     30.000000     43000.000000
# 50%     37.000000     65000.000000
# 75%     46.000000     86000.000000
# max     60.000000    150000.000000

# %%
X_train.shape,X_test.shape
# Out:
# ((280, 2), (120, 2))

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
scaler.fit(X_train)
X_train_scaled=scaler.transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[ 0.20752482,  0.28884937],
#        [-0.75292064,  0.55460344],
#        [ 0.30356937,  0.34790583],
#        [ 0.30356937, -0.47888462],
#        [-1.42523247, -0.15407409],
#        [-0.75292064,  0.6136599 ],
#        [-1.32918792, -1.06944923],
#        [-0.94500974,  0.46601875],
#        [-1.52127702, -0.15407409],
#        [ 0.39961392,  0.64318813],
#        [ 1.45610393,  0.11167999],
#        [-1.80941066, -1.27614684],
#        [-0.27269791,  0.25932114],
#        [ 1.07192575, -1.18756215],
#        [-0.36874246,  0.11167999],
#        [-0.27269791, -0.33124347],
#        [ 0.87983665,  1.08611158],
#        [-1.32918792, -1.3352033 ],
#        [ 0.87983665, -0.50841285],
#        [ 0.7837921 ,  0.3183776 ],
#        [ 0.30356937, -1.12850569],
#        [-0.08060882,  0.34790583],
#        [ 0.30356937,  0.11167999],
#        [ 1.36005939, -0.89227984],
#        [-0.17665336, -0.41982816],
#        [-1.04105428, -1.09897746],
#        [-1.61732156, -1.54190091],
#        [ 0.01543573, -0.39029993],
#        [-0.27269791, -0.71511046],
#        [-0.75292064, -1.51237268],
#        [-0.94500974,  0.55460344],
#        [ 1.45610393,  1.05658335],
#        [-0.17665336, -0.24265878],
#        [-0.6568761 , -1.48284445],
#        [ 0.01543573,  1.32233743],
#        [-0.27269791, -0.53794108],
#        [-1.71336611,  0.17073645],
#        [ 1.93632667, -0.62652577],
#        [ 0.39961392,  0.3183776 ],
#        [ 1.93632667, -1.3352033 ],
#        [-1.04105428,  0.64318813],
#        [-0.94500974, -0.39029993],
#        [-1.23314338,  0.3183776 ],
#        [-1.13709883,  0.11167999],
#        [-0.17665336,  1.46997858],
#        [ 0.01543573, -0.50841285],
#        [ 1.55214848,  0.05262352],
#        [-0.75292064,  1.97195849],
#        [ 1.07192575,  0.58413167],
#        [ 1.74423757,  1.05658335],
#        [-0.27269791, -0.39029993],
#        [ 0.20752482, -0.33124347],
#        [-1.32918792, -1.45331622],
#        [ 0.30356937, -0.27218701],
#        [-1.13709883,  0.37743406],
#        [-0.27269791, -0.86275161],
#        [-1.13709883, -0.74463869],
#        [-1.13709883, -1.57142914],
#        [-1.04105428, -0.30171524],
#        [ 2.03237121,  0.43649052],
#        [ 0.9758812 ,  2.14912788],
#        [ 1.74423757, -0.24265878],
#        [ 0.30356937, -0.47888462],
#        [-0.6568761 , -1.57142914],
#        [-0.84896519, -0.74463869],
#        [-0.84896519, -1.18756215],
#        [ 0.20752482,  0.20026468],
#        [-0.27269791, -0.62652577],
#        [-1.13709883, -1.57142914],
#        [-0.6568761 ,  0.6136599 ],
#        [-0.27269791,  1.17469628],
#        [-0.6568761 , -1.01039277],
#        [ 0.87983665, -0.74463869],
#        [-0.27269791, -0.30171524],
#        [-1.13709883, -1.06944923],
#        [ 0.87983665, -1.3352033 ],
#        [ 0.59170301,  2.09007141],
#        [-0.27269791,  2.32629726],
#        [ 0.87983665,  1.14516805],
#        [-1.23314338,  0.34790583],
#        [-1.52127702, -1.48284445],
#        [-1.04105428,  0.46601875],
#        [ 0.20752482, -0.21313055],
#        [ 0.01543573, -0.21313055],
#        [-0.17665336,  0.20026468],
#        [ 1.07192575, -0.86275161],
#        [ 2.12841576,  1.17469628],
#        [-0.464787  , -0.74463869],
#        [-1.13709883,  0.34790583],
#        [-1.13709883, -0.98086454],
#        [ 0.11148028,  1.94243026],
#        [ 0.01543573,  1.2928092 ],
#        [-0.17665336, -1.039921  ],
#        [ 0.7837921 , -1.06944923],
#        [ 0.20752482,  0.20026468],
#        [ 0.68774756,  0.3183776 ],
#        [ 0.9758812 ,  1.85384557],
#        [ 1.84028212, -1.039921  ],
#        [-0.84896519, -0.74463869],
#        [ 2.03237121, -0.77416692],
#        [-1.23314338, -1.039921  ],
#        [ 0.39961392, -0.44935639],
#        [-1.13709883,  0.52507521],
#        [-1.71336611, -0.56746931],
#        [ 0.30356937, -0.68558223],
#        [-0.17665336,  1.67667619],
#        [ 0.20752482, -0.62652577],
#        [-0.94500974, -0.27218701],
#        [ 1.07192575,  0.17073645],
#        [-0.27269791, -1.42378799],
#        [-0.08060882, -0.33124347],
#        [-0.17665336,  2.23771257],
#        [ 0.87983665,  1.32233743],
#        [ 1.74423757,  1.91290203],
#        [-0.08060882,  0.34790583],
#        [ 0.30356937,  0.11167999],
#        [ 0.68774756, -1.36473153],
#        [-0.56083155,  0.52507521],
#        [ 0.49565846,  1.91290203],
#        [ 1.26401484,  1.94243026],
#        [ 2.03237121,  1.82431734],
#        [ 1.07192575, -0.09501763],
#        [ 0.87983665,  2.23771257],
#        [ 0.9758812 , -1.15803392],
#        [-1.04105428, -1.42378799],
#        [ 0.39961392, -0.09501763],
#        [-1.42523247,  0.40696229],
#        [ 0.39961392,  0.20026468],
#        [-1.52127702, -0.39029993],
#        [ 1.07192575, -0.95133631],
#        [ 2.03237121,  0.22979291],
#        [-0.75292064, -1.57142914],
#        [ 0.9758812 , -0.98086454],
#        [ 0.30356937, -0.50841285],
#        [-0.84896519,  0.20026468],
#        [ 1.55214848,  1.05658335],
#        [ 2.12841576, -0.77416692],
#        [-1.13709883, -0.47888462],
#        [ 0.39961392, -0.12454586],
#        [-0.6568761 ,  0.22979291],
#        [-1.71336611, -0.95133631],
#        [-0.56083155,  0.93847043],
#        [-1.23314338,  0.64318813],
#        [ 0.20752482, -0.33124347],
#        [-0.6568761 ,  1.46997858],
#        [-0.27269791, -1.3352033 ],
#        [-1.80941066,  0.49554698],
#        [-0.75292064,  1.41092212],
#        [ 0.39961392,  1.17469628],
#        [ 0.01543573, -0.21313055],
#        [-0.27269791,  0.84988574],
#        [ 0.11148028, -0.27218701],
#        [-0.08060882, -0.47888462],
#        [ 0.87983665, -0.53794108],
#        [ 0.68774756, -1.06944923],
#        [-0.27269791, -1.36473153],
#        [-0.464787  ,  2.38535372],
#        [ 1.07192575,  0.52507521],
#        [ 0.9758812 ,  2.06054318],
#        [-0.84896519, -0.62652577],
#        [-0.56083155,  1.97195849],
#        [-0.56083155, -1.48284445],
#        [-0.27269791, -0.24265878],
#        [ 1.07192575, -1.18756215],
#        [ 1.16797029, -0.95133631],
#        [ 0.30356937,  0.11167999],
#        [-1.9054552 , -0.00643294],
#        [ 1.84028212, -0.24265878],
#        [ 2.03237121,  0.58413167],
#        [ 0.01543573,  0.08215175],
#        [-0.94500974, -0.92180807],
#        [ 0.30356937, -0.24265878],
#        [ 1.45610393,  2.20818434],
#        [ 0.87983665, -1.27614684],
#        [-0.84896519,  0.43649052],
#        [ 1.16797029, -0.71511046],
#        [-0.17665336,  0.9089422 ],
#        [ 0.20752482, -0.24265878],
#        [ 0.49565846,  1.2928092 ],
#        [ 0.11148028,  0.08215175],
#        [ 0.01543573, -0.53794108],
#        [-1.32918792, -0.39029993],
#        [ 0.20752482, -0.27218701],
#        [ 0.68774756,  1.85384557],
#        [-1.04105428, -0.30171524],
#        [ 0.11148028,  1.94243026],
#        [ 0.9758812 ,  0.17073645],
#        [-1.9054552 ,  0.52507521],
#        [-0.56083155,  1.44045035],
#        [ 0.7837921 , -1.18756215],
#        [-1.80941066,  0.05262352],
#        [ 0.39961392,  0.34790583],
#        [ 1.84028212,  1.5880915 ],
#        [ 0.39961392,  0.05262352],
#        [-0.94500974,  1.61761973],
#        [-0.27269791,  0.58413167],
#        [-0.75292064,  1.14516805],
#        [-0.27269791,  0.14120822],
#        [ 1.07192575,  0.6136599 ],
#        [ 1.93632667, -0.89227984],
#        [-0.84896519,  0.34790583],
#        [-1.04105428,  0.82035751],
#        [-0.08060882,  2.23771257],
#        [-0.08060882, -0.18360232],
#        [ 1.55214848, -1.24661861],
#        [ 1.16797029, -1.42378799],
#        [ 0.30356937,  0.55460344],
#        [-0.27269791,  0.08215175],
#        [-0.94500974,  0.49554698],
#        [-1.23314338, -1.36473153],
#        [ 0.30356937,  0.11167999],
#        [ 0.11148028,  0.08215175],
#        [ 0.9758812 , -1.12850569],
#        [ 0.87983665, -1.12850569],
#        [ 1.45610393,  0.40696229],
#        [ 1.64819303, -0.86275161],
#        [ 0.39961392,  2.38535372],
#        [ 1.36005939, -1.39425976],
#        [ 0.01543573,  0.08215175],
#        [-0.08060882, -1.039921  ],
#        [ 1.84028212, -1.24661861],
#        [ 0.11148028, -0.21313055],
#        [-0.36874246, -0.74463869],
#        [ 0.39961392, -0.41982816],
#        [ 0.7837921 ,  0.17073645],
#        [-1.61732156, -0.00643294],
#        [-0.56083155,  2.41488195],
#        [ 0.87983665, -1.42378799],
#        [-1.80941066, -1.39425976],
#        [-1.42523247, -0.59699754],
#        [-1.13709883, -1.54190091],
#        [-0.6568761 ,  0.08215175],
#        [-0.08060882,  0.20026468],
#        [-0.27269791,  0.20026468],
#        [ 2.12841576, -0.77416692],
#        [-0.27269791,  0.11167999],
#        [-0.75292064,  0.3183776 ],
#        [-0.56083155, -1.48284445],
#        [ 1.84028212,  0.17073645],
#        [-0.27269791,  0.20026468],
#        [ 0.7837921 ,  0.40696229],
#        [ 2.12841576, -1.01039277],
#        [ 0.9758812 , -0.80369515],
#        [ 1.26401484, -1.3352033 ],
#        [-0.27269791, -0.09501763],
#        [-0.75292064, -0.18360232],
#        [-0.464787  , -0.50841285],
#        [ 0.68774756, -1.36473153],
#        [-0.17665336, -0.47888462],
#        [ 0.01543573,  0.34790583],
#        [-0.36874246, -1.27614684],
#        [-0.08060882,  2.03101495],
#        [-1.9054552 , -0.71511046],
#        [-0.84896519, -0.21313055],
#        [ 0.87983665, -1.01039277],
#        [ 0.11148028,  0.82035751],
#        [ 1.93632667,  0.96799866],
#        [ 1.26401484,  2.29676903],
#        [-0.94500974, -0.71511046],
#        [-0.08060882,  0.05262352],
#        [-1.80941066,  0.22979291],
#        [-1.52127702,  0.37743406],
#        [ 0.01543573, -0.09501763],
#        [-1.23314338,  0.55460344],
#        [-1.13709883,  0.34790583],
#        [ 0.39961392,  1.05658335],
#        [-0.08060882, -0.39029993],
#        [-0.464787  , -0.80369515],
#        [-0.27269791, -0.27218701],
#        [-1.32918792, -1.21709038],
#        [-0.6568761 , -0.30171524],
#        [-1.61732156,  0.58413167],
#        [ 1.64819303,  1.82431734],
#        [-0.36874246,  1.38139389],
#        [-0.6568761 , -0.00643294],
#        [ 0.20752482,  2.17865611],
#        [-0.94500974,  0.3183776 ],
#        [-0.08060882,  0.08215175],
#        [ 0.11148028,  0.3183776 ],
#        [ 0.68774756, -0.68558223]])

# %%
X_train_scaled=pd.DataFrame(X_train_scaled,columns=X_train.columns)
X_test_scaled=pd.DataFrame(X_test_scaled,columns=X_test.columns)

# %%
X_train_scaled
# Out:
#           Age  EstimatedSalary
# 0    0.207525         0.288849
# 1   -0.752921         0.554603
# 2    0.303569         0.347906
# 3    0.303569        -0.478885
# 4   -1.425232        -0.154074
# ..        ...              ...
# 275  0.207525         2.178656
# 276 -0.945010         0.318378
# 277 -0.080609         0.082152
# 278  0.111480         0.318378
# 279  0.687748        -0.685582
#
# [280 rows x 2 columns]

# %%
import numpy as np

# %%
np.round(X_train_scaled.describe())
# Out:
#          Age  EstimatedSalary
# count  280.0            280.0
# mean    -0.0             -0.0
# std      1.0              1.0
# min     -2.0             -2.0
# 25%     -1.0             -1.0
# 50%     -0.0             -0.0
# 75%      1.0              1.0
# max      2.0              2.0

# %%
import seaborn as sns

# %%
sns.scatterplot(x = X_train['Age'],y = X_train['EstimatedSalary'])
# Out:
# <Axes: xlabel='Age', ylabel='EstimatedSalary'>

# %%
sns.scatterplot(x = X_train_scaled['Age'],y = X_train_scaled['EstimatedSalary'])
# Out:
# <Axes: xlabel='Age', ylabel='EstimatedSalary'>

# %% [markdown]
# # Even after scaling their nature are same and scaling doesnot change their relation with each other
